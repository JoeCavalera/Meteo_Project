# %%
# Questo notebook popola la tabella dei metadati con le città monitorate dal progetto.
#
# La tabella finale è:
# progetto_meteo.metadati.citta_monitorate
#
# Questa tabella viene usata dalla parte Open-Meteo della pipeline.
# Ogni riga contiene:
# - il nome della città o provincia operativa;
# - la regione;
# - la macroarea finale del progetto;
# - latitudine e longitudine da usare nelle chiamate API Open-Meteo.
#
# Le macroaree usate sono:
# - Nord
# - Centro
# - Sud
# - Isole
#
# Nota importante:
# per la provincia Barletta-Andria-Trani viene usata una sola riga tecnica chiamata BAT.

catalogo = "progetto_meteo"
schema_metadati = "metadati"

spark.sql(f"USE CATALOG {catalogo}")

# Creo la lista delle città monitorate.
# Ogni elemento contiene città, regione, macroarea e coordinate geografiche.
# Questa lista è il riferimento usato da Open-Meteo per scaricare i dati meteo.
#
# La lista è già organizzata per macroarea e regione.

citta_monitorate = [
    # Nord - Valle d'Aosta
    {"citta": "Aosta", "regione": "Valle_d_Aosta", "area": "Nord", "latitudine": 45.7370, "longitudine": 7.3201},

    # Nord - Piemonte
    {"citta": "Alessandria", "regione": "Piemonte", "area": "Nord", "latitudine": 44.9073, "longitudine": 8.6117},
    {"citta": "Asti", "regione": "Piemonte", "area": "Nord", "latitudine": 44.9008, "longitudine": 8.2063},
    {"citta": "Biella", "regione": "Piemonte", "area": "Nord", "latitudine": 45.5629, "longitudine": 8.0583},
    {"citta": "Cuneo", "regione": "Piemonte", "area": "Nord", "latitudine": 44.3845, "longitudine": 7.5427},
    {"citta": "Novara", "regione": "Piemonte", "area": "Nord", "latitudine": 45.4459, "longitudine": 8.6222},
    {"citta": "Torino", "regione": "Piemonte", "area": "Nord", "latitudine": 45.0703, "longitudine": 7.6869},
    {"citta": "Verbania", "regione": "Piemonte", "area": "Nord", "latitudine": 45.9214, "longitudine": 8.5518},
    {"citta": "Vercelli", "regione": "Piemonte", "area": "Nord", "latitudine": 45.3202, "longitudine": 8.4186},

    # Nord - Liguria
    {"citta": "Genova", "regione": "Liguria", "area": "Nord", "latitudine": 44.4056, "longitudine": 8.9463},
    {"citta": "Imperia", "regione": "Liguria", "area": "Nord", "latitudine": 43.8897, "longitudine": 8.0397},
    {"citta": "La Spezia", "regione": "Liguria", "area": "Nord", "latitudine": 44.1025, "longitudine": 9.8241},
    {"citta": "Savona", "regione": "Liguria", "area": "Nord", "latitudine": 44.3091, "longitudine": 8.4772},

    # Nord - Lombardia
    {"citta": "Bergamo", "regione": "Lombardia", "area": "Nord", "latitudine": 45.6983, "longitudine": 9.6773},
    {"citta": "Brescia", "regione": "Lombardia", "area": "Nord", "latitudine": 45.5416, "longitudine": 10.2118},
    {"citta": "Como", "regione": "Lombardia", "area": "Nord", "latitudine": 45.8081, "longitudine": 9.0852},
    {"citta": "Cremona", "regione": "Lombardia", "area": "Nord", "latitudine": 45.1332, "longitudine": 10.0227},
    {"citta": "Lecco", "regione": "Lombardia", "area": "Nord", "latitudine": 45.8566, "longitudine": 9.3977},
    {"citta": "Lodi", "regione": "Lombardia", "area": "Nord", "latitudine": 45.3136, "longitudine": 9.5036},
    {"citta": "Mantova", "regione": "Lombardia", "area": "Nord", "latitudine": 45.1564, "longitudine": 10.7914},
    {"citta": "Milano", "regione": "Lombardia", "area": "Nord", "latitudine": 45.4642, "longitudine": 9.1900},
    {"citta": "Monza", "regione": "Lombardia", "area": "Nord", "latitudine": 45.5845, "longitudine": 9.2744},
    {"citta": "Pavia", "regione": "Lombardia", "area": "Nord", "latitudine": 45.1847, "longitudine": 9.1582},
    {"citta": "Sondrio", "regione": "Lombardia", "area": "Nord", "latitudine": 46.1699, "longitudine": 9.8788},
    {"citta": "Varese", "regione": "Lombardia", "area": "Nord", "latitudine": 45.8206, "longitudine": 8.8251},

    # Nord - Trentino Alto Adige
    {"citta": "Bolzano", "regione": "Trentino_Alto_Adige", "area": "Nord", "latitudine": 46.4983, "longitudine": 11.3548},
    {"citta": "Trento", "regione": "Trentino_Alto_Adige", "area": "Nord", "latitudine": 46.0748, "longitudine": 11.1217},

    # Nord - Veneto
    {"citta": "Belluno", "regione": "Veneto", "area": "Nord", "latitudine": 46.1396, "longitudine": 12.2170},
    {"citta": "Padova", "regione": "Veneto", "area": "Nord", "latitudine": 45.4064, "longitudine": 11.8768},
    {"citta": "Rovigo", "regione": "Veneto", "area": "Nord", "latitudine": 45.0698, "longitudine": 11.7902},
    {"citta": "Treviso", "regione": "Veneto", "area": "Nord", "latitudine": 45.6669, "longitudine": 12.2430},
    {"citta": "Venezia", "regione": "Veneto", "area": "Nord", "latitudine": 45.4408, "longitudine": 12.3155},
    {"citta": "Verona", "regione": "Veneto", "area": "Nord", "latitudine": 45.4384, "longitudine": 10.9916},
    {"citta": "Vicenza", "regione": "Veneto", "area": "Nord", "latitudine": 45.5455, "longitudine": 11.5354},

    # Nord - Friuli Venezia Giulia
    {"citta": "Gorizia", "regione": "Friuli_Venezia_Giulia", "area": "Nord", "latitudine": 45.9402, "longitudine": 13.6202},
    {"citta": "Pordenone", "regione": "Friuli_Venezia_Giulia", "area": "Nord", "latitudine": 45.9569, "longitudine": 12.6605},
    {"citta": "Trieste", "regione": "Friuli_Venezia_Giulia", "area": "Nord", "latitudine": 45.6495, "longitudine": 13.7768},
    {"citta": "Udine", "regione": "Friuli_Venezia_Giulia", "area": "Nord", "latitudine": 46.0711, "longitudine": 13.2346},

    # Nord - Emilia Romagna
    {"citta": "Bologna", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.4949, "longitudine": 11.3426},
    {"citta": "Cesena", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.1391, "longitudine": 12.2432},
    {"citta": "Ferrara", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.8381, "longitudine": 11.6198},
    {"citta": "Forlì", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.2227, "longitudine": 12.0407},
    {"citta": "Modena", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.6471, "longitudine": 10.9252},
    {"citta": "Parma", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.8015, "longitudine": 10.3279},
    {"citta": "Piacenza", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 45.0526, "longitudine": 9.6932},
    {"citta": "Ravenna", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.4184, "longitudine": 12.2035},
    {"citta": "Reggio Emilia", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.6983, "longitudine": 10.6312},
    {"citta": "Rimini", "regione": "Emilia_Romagna", "area": "Nord", "latitudine": 44.0678, "longitudine": 12.5695},

    # Centro - Toscana
    {"citta": "Arezzo", "regione": "Toscana", "area": "Centro", "latitudine": 43.4633, "longitudine": 11.8796},
    {"citta": "Carrara", "regione": "Toscana", "area": "Centro", "latitudine": 44.0793, "longitudine": 10.0977},
    {"citta": "Firenze", "regione": "Toscana", "area": "Centro", "latitudine": 43.7696, "longitudine": 11.2558},
    {"citta": "Grosseto", "regione": "Toscana", "area": "Centro", "latitudine": 42.7635, "longitudine": 11.1124},
    {"citta": "Livorno", "regione": "Toscana", "area": "Centro", "latitudine": 43.5485, "longitudine": 10.3106},
    {"citta": "Lucca", "regione": "Toscana", "area": "Centro", "latitudine": 43.8429, "longitudine": 10.5027},
    {"citta": "Massa", "regione": "Toscana", "area": "Centro", "latitudine": 44.0354, "longitudine": 10.1395},
    {"citta": "Pisa", "regione": "Toscana", "area": "Centro", "latitudine": 43.7228, "longitudine": 10.4017},
    {"citta": "Pistoia", "regione": "Toscana", "area": "Centro", "latitudine": 43.9303, "longitudine": 10.9079},
    {"citta": "Prato", "regione": "Toscana", "area": "Centro", "latitudine": 43.8777, "longitudine": 11.1020},
    {"citta": "Siena", "regione": "Toscana", "area": "Centro", "latitudine": 43.3188, "longitudine": 11.3308},

    # Centro - Marche
    {"citta": "Ancona", "regione": "Marche", "area": "Centro", "latitudine": 43.6158, "longitudine": 13.5189},
    {"citta": "Ascoli Piceno", "regione": "Marche", "area": "Centro", "latitudine": 42.8536, "longitudine": 13.5769},
    {"citta": "Fermo", "regione": "Marche", "area": "Centro", "latitudine": 43.1606, "longitudine": 13.7184},
    {"citta": "Macerata", "regione": "Marche", "area": "Centro", "latitudine": 43.3008, "longitudine": 13.4533},
    {"citta": "Pesaro", "regione": "Marche", "area": "Centro", "latitudine": 43.9125, "longitudine": 12.9155},
    {"citta": "Urbino", "regione": "Marche", "area": "Centro", "latitudine": 43.7252, "longitudine": 12.6363},

    # Centro - Umbria
    {"citta": "Perugia", "regione": "Umbria", "area": "Centro", "latitudine": 43.1107, "longitudine": 12.3908},
    {"citta": "Terni", "regione": "Umbria", "area": "Centro", "latitudine": 42.5636, "longitudine": 12.6427},

    # Centro - Lazio
    {"citta": "Frosinone", "regione": "Lazio", "area": "Centro", "latitudine": 41.6396, "longitudine": 13.3512},
    {"citta": "Latina", "regione": "Lazio", "area": "Centro", "latitudine": 41.4676, "longitudine": 12.9037},
    {"citta": "Rieti", "regione": "Lazio", "area": "Centro", "latitudine": 42.4048, "longitudine": 12.8567},
    {"citta": "Roma", "regione": "Lazio", "area": "Centro", "latitudine": 41.9028, "longitudine": 12.4964},
    {"citta": "Viterbo", "regione": "Lazio", "area": "Centro", "latitudine": 42.4207, "longitudine": 12.1077},

    # Centro - Abruzzo
    {"citta": "Chieti", "regione": "Abruzzo", "area": "Centro", "latitudine": 42.3479, "longitudine": 14.1633},
    {"citta": "L'Aquila", "regione": "Abruzzo", "area": "Centro", "latitudine": 42.3498, "longitudine": 13.3995},
    {"citta": "Pescara", "regione": "Abruzzo", "area": "Centro", "latitudine": 42.4618, "longitudine": 14.2161},
    {"citta": "Teramo", "regione": "Abruzzo", "area": "Centro", "latitudine": 42.6589, "longitudine": 13.7044},

    # Centro - Campania
    {"citta": "Avellino", "regione": "Campania", "area": "Centro", "latitudine": 40.9146, "longitudine": 14.7954},
    {"citta": "Benevento", "regione": "Campania", "area": "Centro", "latitudine": 41.1298, "longitudine": 14.7826},
    {"citta": "Caserta", "regione": "Campania", "area": "Centro", "latitudine": 41.0723, "longitudine": 14.3311},
    {"citta": "Napoli", "regione": "Campania", "area": "Centro", "latitudine": 40.8518, "longitudine": 14.2681},
    {"citta": "Salerno", "regione": "Campania", "area": "Centro", "latitudine": 40.6824, "longitudine": 14.7681},

    # Sud - Molise
    {"citta": "Campobasso", "regione": "Molise", "area": "Sud", "latitudine": 41.5603, "longitudine": 14.6627},
    {"citta": "Isernia", "regione": "Molise", "area": "Sud", "latitudine": 41.5892, "longitudine": 14.1931},

    # Sud - Puglia
    {"citta": "BAT", "regione": "Puglia", "area": "Sud", "latitudine": 41.2748, "longitudine": 16.3298},
    {"citta": "Bari", "regione": "Puglia", "area": "Sud", "latitudine": 41.1171, "longitudine": 16.8719},
    {"citta": "Brindisi", "regione": "Puglia", "area": "Sud", "latitudine": 40.6327, "longitudine": 17.9418},
    {"citta": "Foggia", "regione": "Puglia", "area": "Sud", "latitudine": 41.4622, "longitudine": 15.5446},
    {"citta": "Lecce", "regione": "Puglia", "area": "Sud", "latitudine": 40.3515, "longitudine": 18.1750},
    {"citta": "Taranto", "regione": "Puglia", "area": "Sud", "latitudine": 40.4644, "longitudine": 17.2470},

    # Sud - Basilicata
    {"citta": "Matera", "regione": "Basilicata", "area": "Sud", "latitudine": 40.6664, "longitudine": 16.6043},
    {"citta": "Potenza", "regione": "Basilicata", "area": "Sud", "latitudine": 40.6404, "longitudine": 15.8056},

    # Sud - Calabria
    {"citta": "Catanzaro", "regione": "Calabria", "area": "Sud", "latitudine": 38.9098, "longitudine": 16.5877},
    {"citta": "Cosenza", "regione": "Calabria", "area": "Sud", "latitudine": 39.2983, "longitudine": 16.2537},
    {"citta": "Crotone", "regione": "Calabria", "area": "Sud", "latitudine": 39.0808, "longitudine": 17.1271},
    {"citta": "Reggio Calabria", "regione": "Calabria", "area": "Sud", "latitudine": 38.1113, "longitudine": 15.6473},
    {"citta": "Vibo Valentia", "regione": "Calabria", "area": "Sud", "latitudine": 38.6754, "longitudine": 16.1016},

    # Isole - Sicilia
    {"citta": "Agrigento", "regione": "Sicilia", "area": "Isole", "latitudine": 37.3111, "longitudine": 13.5765},
    {"citta": "Caltanissetta", "regione": "Sicilia", "area": "Isole", "latitudine": 37.4901, "longitudine": 14.0629},
    {"citta": "Catania", "regione": "Sicilia", "area": "Isole", "latitudine": 37.5079, "longitudine": 15.0830},
    {"citta": "Enna", "regione": "Sicilia", "area": "Isole", "latitudine": 37.5676, "longitudine": 14.2799},
    {"citta": "Messina", "regione": "Sicilia", "area": "Isole", "latitudine": 38.1938, "longitudine": 15.5540},
    {"citta": "Palermo", "regione": "Sicilia", "area": "Isole", "latitudine": 38.1157, "longitudine": 13.3615},
    {"citta": "Ragusa", "regione": "Sicilia", "area": "Isole", "latitudine": 36.9269, "longitudine": 14.7255},
    {"citta": "Siracusa", "regione": "Sicilia", "area": "Isole", "latitudine": 37.0755, "longitudine": 15.2866},
    {"citta": "Trapani", "regione": "Sicilia", "area": "Isole", "latitudine": 38.0176, "longitudine": 12.5362},

    # Isole - Sardegna
    {"citta": "Cagliari", "regione": "Sardegna", "area": "Isole", "latitudine": 39.2238, "longitudine": 9.1217},
    {"citta": "Carbonia", "regione": "Sardegna", "area": "Isole", "latitudine": 39.1647, "longitudine": 8.5214},
    {"citta": "Iglesias", "regione": "Sardegna", "area": "Isole", "latitudine": 39.3092, "longitudine": 8.5377},
    {"citta": "Lanusei", "regione": "Sardegna", "area": "Isole", "latitudine": 39.8756, "longitudine": 9.5415},
    {"citta": "Nuoro", "regione": "Sardegna", "area": "Isole", "latitudine": 40.3202, "longitudine": 9.3264},
    {"citta": "Olbia", "regione": "Sardegna", "area": "Isole", "latitudine": 40.9236, "longitudine": 9.4964},
    {"citta": "Oristano", "regione": "Sardegna", "area": "Isole", "latitudine": 39.9038, "longitudine": 8.5912},
    {"citta": "Sanluri", "regione": "Sardegna", "area": "Isole", "latitudine": 39.5612, "longitudine": 8.8998},
    {"citta": "Sassari", "regione": "Sardegna", "area": "Isole", "latitudine": 40.7259, "longitudine": 8.5557},
    {"citta": "Tempio Pausania", "regione": "Sardegna", "area": "Isole", "latitudine": 40.9001, "longitudine": 9.1049},
    {"citta": "Tortolì", "regione": "Sardegna", "area": "Isole", "latitudine": 39.9260, "longitudine": 9.6576},
    {"citta": "Villacidro", "regione": "Sardegna", "area": "Isole", "latitudine": 39.4573, "longitudine": 8.7410}
]

# Creo il DataFrame Spark partendo dalla lista delle città.
# Seleziono le colonne nello stesso ordine previsto dalla tabella finale.
df_citta = (
    spark.createDataFrame(citta_monitorate)
    .select(
        "citta",
        "regione",
        "area",
        "latitudine",
        "longitudine"
    )
)

# Sovrascrivo la tabella dei metadati.
# Uso overwrite perché questo notebook definisce la lista ufficiale delle città monitorate.

df_citta.write.mode("overwrite").format("delta").option("overwriteSchema", "true").saveAsTable(
    f"{catalogo}.{schema_metadati}.citta_monitorate"
)

# Controllo quante città sono state salvate.
print("Città monitorate:", df_citta.count())

# Mostro la tabella finale ordinata per area, regione e città.
display(
    spark.table(f"{catalogo}.{schema_metadati}.citta_monitorate")
    .orderBy("area", "regione", "citta")
)
